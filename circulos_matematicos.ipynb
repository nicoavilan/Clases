# %% [markdown]
# <a href="https://colab.research.google.com/github/nicoavilan/Clases/blob/main/circulos_matematicos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Iniciación en la Ciencia de datos**
#
# Nicolás Avilán Vargas, PhD.
#
# Director de Ciencia de Datos
#
# Facultad de Ingeniería y Ciencias Básicas
#
# Universidad Central

# %% [markdown]
# ## Librerías

# %%
import numpy as np # Para manipular números
import pandas as pd # Para manipular tablas de datos
import matplotlib.pyplot as plt # Para hacer gráficas

# %% [markdown]
# ## Cargue de datos

# %%
url = "https://raw.githubusercontent.com/nicoavilan/Bases-de-datos/main/temperatura.csv"
df = pd.read_csv(url)
df
# Out:
#     Temperatura  Ventas
# 0            37     292
# 1            40     228
# 2            49     324
# 3            61     376
# 4            72     440
# 5            79     496
# 6            83     536
# 7            81     556
# 8            75     496
# 9            64     412
# 10           53     324
# 11           42     320

# %% [markdown]
# ## Exploración de datos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperatura  12 non-null     int64
#  1   Ventas       12 non-null     int64
# dtypes: int64(2)
# memory usage: 320.0 bytes

# %%
df.describe()
# Out:
#        Temperatura      Ventas
# count    12.000000   12.000000
# mean     61.333333  400.000000
# std      16.837908  105.651227
# min      37.000000  228.000000
# 25%      47.250000  323.000000
# 50%      62.500000  394.000000
# 75%      76.000000  496.000000
# max      83.000000  556.000000

# %% [markdown]
# Redondeo los resultados con una cifra decimal.

# %%
round(df.describe(), 1)
# Out:
#        Temperatura  Ventas
# count         12.0    12.0
# mean          61.3   400.0
# std           16.8   105.7
# min           37.0   228.0
# 25%           47.2   323.0
# 50%           62.5   394.0
# 75%           76.0   496.0
# max           83.0   556.0

# %%
df.Temperatura
# Out:
# 0     37
# 1     40
# 2     49
# 3     61
# 4     72
# 5     79
# 6     83
# 7     81
# 8     75
# 9     64
# 10    53
# 11    42
# Name: Temperatura, dtype: int64

# %% [markdown]
# **Ejercicio:** ¿cómo imprimo los valores de la columna *Ventas*?

# %% [markdown]
# Valores máximos y mínimos de cada columna

# %%
df.Temperatura.max()
# Out:
# 83

# %%
df.Temperatura.min()
# Out:
# 37

# %%
df.Temperatura.mean()
# Out:
# 61.333333333333336

# %% [markdown]
# **Ejercicio:** ¿cómo imprimo los valores máximo, mínimo y promedio de la columna *Ventas*?

# %% [markdown]
# ##  Visualización de datos

# %%
plt.plot(df.Temperatura, df.Ventas)
plt.show()

# %%
df
# Out:
#     Temperatura  Ventas
# 0            37     292
# 1            40     228
# 2            49     324
# 3            61     376
# 4            72     440
# 5            79     496
# 6            83     536
# 7            81     556
# 8            75     496
# 9            64     412
# 10           53     324
# 11           42     320

# %%
df.sort_values("Temperatura", inplace = True)

# %%
df
# Out:
#     Temperatura  Ventas
# 0            37     292
# 1            40     228
# 11           42     320
# 2            49     324
# 10           53     324
# 3            61     376
# 9            64     412
# 4            72     440
# 8            75     496
# 5            79     496
# 7            81     556
# 6            83     536

# %% [markdown]
# Ahora ordeno los índices de las filas en la tabla

# %%
df.reset_index(drop = True, inplace = True)

# %%
df
# Out:
#     Temperatura  Ventas
# 0            37     292
# 1            40     228
# 2            42     320
# 3            49     324
# 4            53     324
# 5            61     376
# 6            64     412
# 7            72     440
# 8            75     496
# 9            79     496
# 10           81     556
# 11           83     536

# %% [markdown]
# ¡Ahora la gráfica queda mejor!

# %%
plt.plot(df.Temperatura, df.Ventas)
plt.show()

# %% [markdown]
# Puede ser mejorada agregando un título y nombres a los ejes.

# %% [markdown]
# ## ¿Cómo calcular una nueva columna?

# %% [markdown]
# Hay que tener en cuenta que la transformación de temperatura de grados Fahrenheit a Celcius se hace con la siguiente ecuación:
#
# $$ C = \frac{5}{9}(F-32) $$
#
# Ahora calculo una nueva columna con las temperaturas en grados Celcius.

# %%
df["Celsius"] = np.round((5/9)*(df.Temperatura - 32), 1)

# %%
df
# Out:
#     Temperatura  Ventas  Celsius
# 0            37     292      2.8
# 1            40     228      4.4
# 2            42     320      5.6
# 3            49     324      9.4
# 4            53     324     11.7
# 5            61     376     16.1
# 6            64     412     17.8
# 7            72     440     22.2
# 8            75     496     23.9
# 9            79     496     26.1
# 10           81     556     27.2
# 11           83     536     28.3

# %% [markdown]
# **Ejercicio:** Graficar los valores de temperatura en Celcius y Ventas de helado. Hay que generar una gráfica como la siguiente:
#
# ![image.png](data:image/png;base64,...)
